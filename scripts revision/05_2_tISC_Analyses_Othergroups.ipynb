# %% [markdown]
# ### Analyses across ages
#
# #### Import modules

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from nilearn import input_data, datasets
import sys, os, nilearn, pickle
from nilearn import plotting
from nilearn.input_data import NiftiMasker
import seaborn as sns
import pandas as pd
from utils import *
from nilearn import input_data
import nibabel as nib
from nilearn.image import new_img_like, load_img, get_data
sns.set_style('white')
# Out:
# /opt/anaconda3/envs/neuroimaging/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
act_segments = [ 'Act  A    0:14 1:30    Secs( 14 -  90)   TRs (  7 -  45)   Premise: Clouds produce babies and storks deliver them',
                 'Act  B    1:30 3:53    Secs( 90 - 233)   TRs ( 45 - 116)   Exposition: Gus, the cloud, makes bad babies, which hurt Peck, the stork',
                 'Act C/D   3:53 4:35    Secs(233 - 275)   TRs (116 - 138)   Conflict & Climax: Peck leaves for another cloud, Gus is sad',
                 'Act  E    4:35 5:14    Secs(275 - 314)   TRs (138 - 157)   Resolution: Peck returns. He carries protective gear. Happily ever after ']

onsets = np.array([7, 45, 116, 138])
print(onsets)

offsets = np.hstack((onsets[1:], 157))
print(offsets)


onsets = onsets + 5 + 2   # the onset and hrf delay
print(onsets)
offsets = offsets + 5 + 2   
print(offsets)

n_bins = len(onsets)
n_bins
# Out:
# [  7  45 116 138]
# [ 45 116 138 157]
# [ 14  52 123 145]
# [ 52 123 145 164]
# 4

# %%
array_filename = ['../data/ts_array_mentalizingfine_regional_average_ages8-13.npy',
                  '../data/ts_array_mentalizingfine_regional_average_ages5-8.npy',
                  '../data/ts_array_mentalizingfine_regional_average_ages3-5.npy',]
names = ['8-13 years',
         '5-8 years',
         '3-5 years',]

# %%
for (current_array_filename, current_name) in zip(array_filename, names):
    loop_tisc_groups(current_array_filename, current_name, onsets, offsets)
